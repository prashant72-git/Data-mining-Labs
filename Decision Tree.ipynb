# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt

# %%
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.cleveland.data"
column_names = ["age", "sex", "cp", "trestbps", "chol", "fbs", "restecg", "thalach", "exang", "oldpeak", "slope", "ca", "thal", "num"]

# Reading the dataset
heart_disease_data = pd.read_csv(url, names=column_names, na_values="?")

# Drop rows with missing values
heart_disease_data.dropna(inplace=True)

# Convert categorical features to numerical using one-hot encoding
categorical_features = ['cp', 'restecg', 'slope', 'thal']
heart_disease_data = pd.get_dummies(heart_disease_data, columns=categorical_features)

# %%
# Features and target variable
X = heart_disease_data.drop('num', axis=1)
y = heart_disease_data['num'].apply(lambda x: 1 if x > 0 else 0)  # Binary classification (presence of heart disease)

# Split the dataset into training and test sets (70% train, 30% test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=10)

# Standardize the features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Initialize the decision tree model
decision_tree = DecisionTreeClassifier(random_state=10)

# Train the decision tree model
decision_tree.fit(X_train, y_train)

# Predict the class values
y_train_pred = decision_tree.predict(X_train)
y_test_pred = decision_tree.predict(X_test)

# %%
# Calculate and display the accuracy
train_accuracy = accuracy_score(y_train, y_train_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)
print(f"Training Accuracy: {train_accuracy:.2f}")
print(f"Test Accuracy: {test_accuracy:.2f}")

# Display the confusion matrix
conf_matrix = confusion_matrix(y_test, y_test_pred)
print("Confusion Matrix:")
print(conf_matrix)

# Display the classification report
class_report = classification_report(y_test, y_test_pred)
print("Classification Report:")
print(class_report)
# Out:
# Training Accuracy: 1.00
# Test Accuracy: 0.78
# Confusion Matrix:
# [[44 12]
#  [ 8 26]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.79      0.81        56
#            1       0.68      0.76      0.72        34
#
#     accuracy                           0.78        90
#    macro avg       0.77      0.78      0.77        90
# weighted avg       0.78      0.78      0.78        90

# %%
# Visualize the decision tree
plt.figure(figsize=(20, 10))
plot_tree(decision_tree, filled=True, feature_names=X.columns, class_names=['No Disease', 'Disease'], rounded=True)
plt.show()

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt

# Load the Bank Marketing dataset
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/00222/bank-additional-full.csv"
bank_data = pd.read_csv(url, names=coulmn_names, sep=';')

# Display the first few rows of the dataset to understand its structure
print(bank_data.head())

# Convert categorical features to numerical using one-hot encoding
categorical_features = ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'day_of_week', 'poutcome']
bank_data_encoded = pd.get_dummies(bank_data, columns=categorical_features)

# Features and target variable
X = bank_data_encoded.drop('y', axis=1)
y = bank_data_encoded['y'].apply(lambda x: 1 if x == 'yes' else 0)  # Binary classification (yes/no)

# Split the dataset into training and test sets (70% train, 30% test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=10)

# Standardize the features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Initialize the decision tree model
decision_tree = DecisionTreeClassifier(random_state=10)

# Train the decision tree model
decision_tree.fit(X_train, y_train)

# Predict the class values
y_train_pred = decision_tree.predict(X_train)
y_test_pred = decision_tree.predict(X_test)

# Calculate and display the accuracy
train_accuracy = accuracy_score(y_train, y_train_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)
print(f"Training Accuracy: {train_accuracy:.2f}")
print(f"Test Accuracy: {test_accuracy:.2f}")

# Display the confusion matrix
conf_matrix = confusion_matrix(y_test,y_test_pred)
print("Confusion Matrix:")
print(conf_matrix)

# Display the classification report
class_report = classification_report(y_test, y_test_pred)
print("Classification Report:")
print(class_report)

# Visualize the decision tree
plt.figure(figsize=(20, 10))
plot_tree(decision_tree, filled=True, feature_names=X.columns, class_names=['No Disease', 'Disease'], rounded=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-21-5e4b3cd96c3c> in <cell line: 11>()
#       9 # Load the Bank Marketing dataset
#      10 url = "https://archive.ics.uci.edu/ml/machine-learning-databases/00222/bank-additional-full.csv"
# ---> 11 bank_data = pd.read_csv(url, sep=';')
#      12
#      13 # Display the first few rows of the dataset to understand its structure
#
# ...
